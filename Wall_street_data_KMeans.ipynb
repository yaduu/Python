# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
data=pd.read_csv('wall_street_data.csv')

# %%
data.head()
# Out:
#          Unnamed: 0  2010-01-04  2010-01-05  2010-01-06  2010-01-07  \
# 0             Apple    0.580000   -0.220005   -3.409998   -1.170000
# 1               AIG   -0.640002   -0.650000   -0.210001   -0.420000
# 2            Amazon   -2.350006    1.260009   -2.350006   -2.009995
# 3  American express    0.109997    0.000000    0.260002    0.720002
# 4            Boeing    0.459999    1.770000    1.549999    2.690003
#
#    2010-01-08  2010-01-11  2010-01-12  2010-01-13  2010-01-14     ...      \
# 0    1.680011   -2.689994   -1.469994    2.779997   -0.680003     ...
# 1    0.710001   -0.200001   -1.130001    0.069999   -0.119999     ...
# 2    2.960006   -2.309997   -1.640007    1.209999   -1.790001     ...
# 3    0.190003   -0.270001    0.750000    0.300004    0.639999     ...
# 4    0.059997   -1.080002    0.360000    0.549999    0.530002     ...
#
#    2013-10-16  2013-10-17  2013-10-18  2013-10-21  2013-10-22  2013-10-23  \
# ...

# %%
del data['Unnamed: 0']

# %%
samples=data.values

# %%
samples
# Out:
# array([[ 5.8000000e-01, -2.2000500e-01, -3.4099980e+00, ...,
#         -5.3599620e+00,  8.4001900e-01, -1.9589981e+01],
#        [-6.4000200e-01, -6.5000000e-01, -2.1000100e-01, ...,
#         -4.0001000e-02, -4.0000200e-01,  6.6000000e-01],
#        [-2.3500060e+00,  1.2600090e+00, -2.3500060e+00, ...,
#          4.7900090e+00, -1.7600090e+00,  3.7400210e+00],
#        ...,
#        [ 4.3000100e-01,  2.2999600e-01,  5.7000000e-01, ...,
#         -2.6000200e-01,  4.0000100e-01,  4.8000300e-01],
#        [ 9.0000000e-02,  1.0000000e-02, -8.0000000e-02, ...,
#         -3.0000000e-02,  2.0000000e-02, -3.0000000e-02],
#        [ 1.5999900e-01,  1.0001000e-02,  0.0000000e+00, ...,
#         -6.0001000e-02,  2.5999800e-01,  9.9998000e-02]])

# %%
from sklearn import preprocessing

# %%
normalized= preprocessing.normalize(samples)

# %%
normalized
# Out:
# array([[ 0.00302051, -0.00114574, -0.01775851, ..., -0.02791349,
#          0.00437463, -0.10202026],
#        [-0.02599391, -0.02639998, -0.00852927, ..., -0.00162466,
#         -0.01624623,  0.02680614],
#        [-0.02208986,  0.01184398, -0.02208986, ...,  0.04502568,
#         -0.01654394,  0.03515588],
#        ...,
#        [ 0.01981027,  0.01059598,  0.02626006, ..., -0.01197837,
#          0.01842816,  0.02211388],
#        [ 0.0200991 ,  0.00223323, -0.01786587, ..., -0.0066997 ,
#          0.00446647, -0.0066997 ],
#        [ 0.01796837,  0.00112314,  0.        , ..., -0.00673829,
#          0.02919855,  0.01123007]])

# %%
ks=range(1,60)
inertias=[]

for k in ks:
    model=KMeans(n_clusters=k)
    model.fit(normalized)
    inertias.append(model.inertia_)

# %%
inertias
# Out:
# [35.665008628263585,
#  33.30503959597532,
#  32.15697323767716,
#  30.863994572794034,
#  29.803168472181778,
#  28.808481613415033,
#  27.800172221585285,
#  27.418309341187257,
#  26.396144136618716,
#  25.694099834650075,
#  24.8039795638552,
#  23.92432513631773,
#  23.068644105187676,
#  22.103067377560237,
#  21.56639236779634,
#  20.872664409742864,
#  20.158786105164737,
#  19.47853550992162,
#  18.658973437729557,
#  18.116688294213237,
#  17.634510058988614,
#  16.789772548760073,
#  16.3073251233481,
#  15.773770368891702,
#  14.928332162992078,
#  14.441479747728605,
#  13.778265909690884,
#  13.345895974144344,
#  12.64446383019399,
#  12.008398402069439,
#  11.482752286771015,
#  10.959372509004046,
#  10.55462297713649,
#  9.872016010198239,
#  9.478296351970656,
#  8.881595215698155,
#  8.56002052552055,
#  7.866504273761864,
#  7.518099778983995,
#  7.027258930093119,
#  6.599464370864082,
#  6.242375227242817,
#  5.692037280109453,
#  5.337133795515906,
# ...

# %%
sns.lineplot(range(1,60),inertias)

# %%
model=KMeans(n_clusters=10)

# %%
labels=model.fit_predict(samples)

# %%
labels
# Out:
# array([1, 0, 4, 8, 9, 0, 8, 0, 7, 0, 8, 0, 8, 8, 0, 0, 0, 2, 5, 0, 0, 0,
#        0, 6, 0, 0, 8, 0, 0, 9, 3, 0, 8, 0, 0, 8, 9, 0, 0, 0, 0, 0, 8, 8,
#        8, 0, 0, 0, 8, 8, 0, 0, 0, 0, 0, 0, 0, 8, 0, 0])

# %%
df=pd.DataFrame({'labels':labels,'brand':data['Unnamed: 0']})

# %%
df.sort_values(ascending=True,by='labels')
# Out:
#     labels                               brand
# 59       0                               Yahoo
# 20       0                          Home Depot
# 21       0                               Honda
# 22       0                                  HP
# 41       0                       Philip Morris
# 24       0                               Intel
# 25       0                   Johnson & Johnson
# 19       0                     GlaxoSmithKline
# 40       0                      Procter Gamble
# 28       0                           Coca Cola
# 58       0                               Xerox
# 39       0                              Pfizer
# 31       0                           McDonalds
# 38       0                               Pepsi
# 33       0                           Microsoft
# 27       0                      Kimberly-Clark
# 45       0                                Sony
# 46       0                      Sanofi-Aventis
# 16       0                   General Electrics
# ...

# %%
df

# %%
.71/2
# Out:
# 0.355
